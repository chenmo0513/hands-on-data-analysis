# %% [markdown]
# **复习：**在前面我们已经学习了Pandas基础，知道利用Pandas读取csv数据的增删查改，今天我们要学习的就是**探索性数据分析**，主要介绍如何利用Pandas进行排序、算术计算以及计算描述函数describe()的使用。

# %% [markdown]
# # 1 第一章：探索性数据分析

# %% [markdown]
# #### 开始之前，导入numpy、pandas包和数据

# %%
#加载所需的库
import numpy as np
import pandas as pd

# %%
# 载入之前保存的train_chinese.csv数据，关于泰坦尼克号的任务，我们就使用这个数据
df=pd.read_csv("train_chinese.csv")

# %% [markdown]
# ### 1.6 了解你的数据吗？
# 教材《Python for Data Analysis》第五章

# %% [markdown]
# #### 1.6.1 任务一：利用Pandas对示例数据进行排序，要求升序

# %%
# 具体请看《利用Python进行数据分析》第五章 排序和排名 部分

#自己构建一个都为数字的DataFrame数据

'''
我们举了一个例子
pd.DataFrame() ：创建一个DataFrame对象 
np.arange(8).reshape((2, 4)) : 生成一个二维数组（2*4）,第一列：0，1，2，3 第二列：4，5，6，7
index=[2，1] ：DataFrame 对象的索引列
columns=['d', 'a', 'b', 'c'] ：DataFrame 对象的索引行
'''

# %% [markdown]
# 【代码解析】
#
# pd.DataFrame() ：创建一个DataFrame对象
#
# np.arange(8).reshape((2, 4)) : 生成一个二维数组（2*4）,第一列：0，1，2，3 第二列：4，5，6，7
#
# index=['2, 1] ：DataFrame 对象的索引列
#
# columns=['d', 'a', 'b', 'c'] ：DataFrame 对象的索引行

# %% [markdown]
# 【问题】：大多数时候我们都是想根据列的值来排序,所以将你构建的DataFrame中的数据根据某一列，升序排列

# %%
#回答代码
pd.DataFrame()
np.arange(8).reshape((2, 4))
index=[2, 1]
columns=['d', 'a', 'b', 'c']
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %% [markdown]
# 【思考】通过书本你能说出Pandas对DataFrame数据的其他排序方式吗？

# %% [markdown]
# 【总结】下面将不同的排序方式做一个总结

# %% [markdown]
# 1.让行索引升序排序

# %%
#代码
df.sort_index()
# Out:
#      乘客ID  是否幸存  仓位等级                                                 姓名  \
# 0       1     0     3                            Braund, Mr. Owen Harris
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     1     3                             Heikkinen, Miss. Laina
# 3       4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5     0     3                           Allen, Mr. William Henry
# ..    ...   ...   ...                                                ...
# 886   887     0     2                              Montvila, Rev. Juozas
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 888   889     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1     1                              Behr, Mr. Karl Howell
# 890   891     0     3                                Dooley, Mr. Patrick
#
#          性别    年龄  兄弟姐妹个数  父母子女个数              船票信息       票价    客舱 登船港口
# 0      male  22.0       1       0         A/5 21171   7.2500   NaN    S
# 1    female  38.0       1       0          PC 17599  71.2833   C85    C
# 2    female  26.0       0       0  STON/O2. 3101282   7.9250   NaN    S
# 3    female  35.0       1       0            113803  53.1000  C123    S
# 4      male  35.0       0       0            373450   8.0500   NaN    S
# ..      ...   ...     ...     ...               ...      ...   ...  ...
# 886    male  27.0       0       0            211536  13.0000   NaN    S
# 887  female  19.0       0       0            112053  30.0000   B42    S
# 888  female   NaN       1       2        W./C. 6607  23.4500   NaN    S
# 889    male  26.0       0       0            111369  30.0000  C148    C
# 890    male  32.0       0       0            370376   7.7500   NaN    Q
#
# [891 rows x 12 columns]

# %% [markdown]
# 2.让列索引升序排序

# %%
#代码
df.sort_index(1)
# Out:
# C:\Users\natha\AppData\Local\Temp/ipykernel_12144/629177029.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.sort_index will be keyword-only
#   df.sort_index(1)
#      乘客ID  仓位等级  兄弟姐妹个数                                                 姓名  \
# 0       1     3       1                            Braund, Mr. Owen Harris
# 1       2     1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     3       0                             Heikkinen, Miss. Laina
# 3       4     1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5     3       0                           Allen, Mr. William Henry
# ..    ...   ...     ...                                                ...
# 886   887     2       0                              Montvila, Rev. Juozas
# 887   888     1       0                       Graham, Miss. Margaret Edith
# 888   889     3       1           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1       0                              Behr, Mr. Karl Howell
# 890   891     3       0                                Dooley, Mr. Patrick
#
#        客舱    年龄      性别  是否幸存  父母子女个数 登船港口       票价              船票信息
# 0     NaN  22.0    male     0       0    S   7.2500         A/5 21171
# 1     C85  38.0  female     1       0    C  71.2833          PC 17599
# 2     NaN  26.0  female     1       0    S   7.9250  STON/O2. 3101282
# 3    C123  35.0  female     1       0    S  53.1000            113803
# 4     NaN  35.0    male     0       0    S   8.0500            373450
# ..    ...   ...     ...   ...     ...  ...      ...               ...
# 886   NaN  27.0    male     0       0    S  13.0000            211536
# 887   B42  19.0  female     1       0    S  30.0000            112053
# 888   NaN   NaN  female     0       2    S  23.4500        W./C. 6607
# 889  C148  26.0    male     1       0    C  30.0000            111369
# 890   NaN  32.0    male     0       0    Q   7.7500            370376
#
# [891 rows x 12 columns]

# %% [markdown]
# 3.让列索引降序排序

# %%
#代码
df.columns.to_list()
df.sort_values(by=df.columns.to_list(),axis=0)
# Out:
# ['乘客ID',
#  '是否幸存',
#  '仓位等级',
#  '姓名',
#  '性别',
#  '年龄',
#  '兄弟姐妹个数',
#  '父母子女个数',
#  '船票信息',
#  '票价',
#  '客舱',
#  '登船港口']
#      乘客ID  是否幸存  仓位等级                                                 姓名  \
# 0       1     0     3                            Braund, Mr. Owen Harris
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     1     3                             Heikkinen, Miss. Laina
# 3       4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5     0     3                           Allen, Mr. William Henry
# ..    ...   ...   ...                                                ...
# 886   887     0     2                              Montvila, Rev. Juozas
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 888   889     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1     1                              Behr, Mr. Karl Howell
# 890   891     0     3                                Dooley, Mr. Patrick
#
#          性别    年龄  兄弟姐妹个数  父母子女个数              船票信息       票价    客舱 登船港口
# 0      male  22.0       1       0         A/5 21171   7.2500   NaN    S
# 1    female  38.0       1       0          PC 17599  71.2833   C85    C
# 2    female  26.0       0       0  STON/O2. 3101282   7.9250   NaN    S
# 3    female  35.0       1       0            113803  53.1000  C123    S
# 4      male  35.0       0       0            373450   8.0500   NaN    S
# ..      ...   ...     ...     ...               ...      ...   ...  ...
# 886    male  27.0       0       0            211536  13.0000   NaN    S
# 887  female  19.0       0       0            112053  30.0000   B42    S
# 888  female   NaN       1       2        W./C. 6607  23.4500   NaN    S
# 889    male  26.0       0       0            111369  30.0000  C148    C
# 890    male  32.0       0       0            370376   7.7500   NaN    Q
#
# [891 rows x 12 columns]

# %% [markdown]
# 4.让任选两列数据同时降序排序

# %%
#代码
df.sort_values(by=['姓名','年龄'],ascending=False)
# Out:
#      乘客ID  是否幸存  仓位等级                                     姓名      性别    年龄  \
# 868   869     0     3            van Melkebeke, Mr. Philemon    male   NaN
# 153   154     0     3        van Billiard, Mr. Austin Blyler    male  40.5
# 361   362     0     2              del Carlo, Mr. Sebastiano    male  29.0
# 282   283     0     3              de Pelsmaeker, Mr. Alfons    male  16.0
# 286   287     1     3                de Mulder, Mr. Theodore    male  30.0
# ..    ...   ...   ...                                    ...     ...   ...
# 874   875     1     2  Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0
# 308   309     0     2                    Abelson, Mr. Samuel    male  30.0
# 279   280     1     3       Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0
# 746   747     0     3            Abbott, Mr. Rossmore Edward    male  16.0
# 845   846     0     3                    Abbing, Mr. Anthony    male  42.0
#
#      兄弟姐妹个数  父母子女个数           船票信息       票价   客舱 登船港口
# 868       0       0         345777   9.5000  NaN    S
# 153       0       2       A/5. 851  14.5000  NaN    S
# 361       1       0  SC/PARIS 2167  27.7208  NaN    C
# 282       0       0         345778   9.5000  NaN    S
# 286       0       0         345774   9.5000  NaN    S
# ..      ...     ...            ...      ...  ...  ...
# 874       1       0      P/PP 3381  24.0000  NaN    C
# 308       1       0      P/PP 3381  24.0000  NaN    C
# 279       1       1      C.A. 2673  20.2500  NaN    S
# 746       1       1      C.A. 2673  20.2500  NaN    S
# 845       0       0      C.A. 5547   7.5500  NaN    S
#
# [891 rows x 12 columns]

# %% [markdown]
# #### 1.6.2 任务二：对泰坦尼克号数据（trian.csv）按票价和年龄两列进行综合排序（降序排列），从这个数据中你可以分析出什么？

# %%
'''
在开始我们已经导入了train_chinese.csv数据，而且前面我们也学习了导入数据过程，根据上面学习，我们直接对目标列进行排序即可
head(20) : 读取前20条数据

'''

# %%
#代码
df1= pd.read_csv('train_chinese.csv')
df1.sort_values(by=["票价","年龄"],ascending=False).head(20)
# Out:
#      乘客ID  是否幸存  仓位等级                                                 姓名  \
# 679   680     1     1                 Cardeza, Mr. Thomas Drake Martinez
# 258   259     1     1                                   Ward, Miss. Anna
# 737   738     1     1                             Lesurer, Mr. Gustave J
# 438   439     0     1                                  Fortune, Mr. Mark
# 341   342     1     1                     Fortune, Miss. Alice Elizabeth
# 88     89     1     1                         Fortune, Miss. Mabel Helen
# 27     28     0     1                     Fortune, Mr. Charles Alexander
# 742   743     1     1              Ryerson, Miss. Susan Parker "Suzette"
# 311   312     1     1                         Ryerson, Miss. Emily Borie
# 299   300     1     1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 118   119     0     1                           Baxter, Mr. Quigg Edmond
# 380   381     1     1                              Bidois, Miss. Rosalie
# 716   717     1     1                      Endres, Miss. Caroline Louise
# 700   701     1     1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 557   558     0     1                                Robbins, Mr. Victor
# 527   528     0     1                                 Farthing, Mr. John
# 377   378     0     1                          Widener, Mr. Harry Elkins
# 779   780     1     1  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...
# 730   731     1     1                      Allen, Miss. Elisabeth Walton
# 689   690     1     1                  Madill, Miss. Georgette Alexandra
#
#          性别    年龄  兄弟姐妹个数  父母子女个数      船票信息        票价               客舱 登船港口
# 679    male  36.0       0       1  PC 17755  512.3292      B51 B53 B55    C
# 258  female  35.0       0       0  PC 17755  512.3292              NaN    C
# 737    male  35.0       0       0  PC 17755  512.3292             B101    C
# 438    male  64.0       1       4     19950  263.0000      C23 C25 C27    S
# 341  female  24.0       3       2     19950  263.0000      C23 C25 C27    S
# 88   female  23.0       3       2     19950  263.0000      C23 C25 C27    S
# 27     male  19.0       3       2     19950  263.0000      C23 C25 C27    S
# 742  female  21.0       2       2  PC 17608  262.3750  B57 B59 B63 B66    C
# 311  female  18.0       2       2  PC 17608  262.3750  B57 B59 B63 B66    C
# 299  female  50.0       0       1  PC 17558  247.5208          B58 B60    C
# 118    male  24.0       0       1  PC 17558  247.5208          B58 B60    C
# 380  female  42.0       0       0  PC 17757  227.5250              NaN    C
# 716  female  38.0       0       0  PC 17757  227.5250              C45    C
# 700  female  18.0       1       0  PC 17757  227.5250          C62 C64    C
# 557    male   NaN       0       0  PC 17757  227.5250              NaN    C
# 527    male   NaN       0       0  PC 17483  221.7792              C95    S
# 377    male  27.0       0       2    113503  211.5000              C82    C
# 779  female  43.0       0       1     24160  211.3375               B3    S
# 730  female  29.0       0       0     24160  211.3375               B5    S
# 689  female  15.0       0       1     24160  211.3375               B5    S

# %% [markdown]
# 【思考】排序后，如果我们仅仅关注年龄和票价两列。根据常识我知道发现票价越高的应该客舱越好，所以我们会明显看出，票价前20的乘客中存活的有14人，这是相当高的一个比例，那么我们后面是不是可以进一步分析一下票价和存活之间的关系，年龄和存活之间的关系呢？当你开始发现数据之间的关系了，数据分析就开始了。
#
# 当然，这只是我的想法，你还可以有更多想法，欢迎写在你的学习笔记中。

# %% [markdown]
# **多做几个数据的排序**

# %%
#代码
df1.sort_values(by=["仓位等级"]).head(20)
# Out:
#      乘客ID  是否幸存  仓位等级                                                 姓名  \
# 445   446     1     1                          Dodge, Master. Washington
# 310   311     1     1                     Hays, Miss. Margaret Bechstein
# 309   310     1     1                     Francatelli, Miss. Laura Mabel
# 307   308     1     1  Penasco y Castellana, Mrs. Victor de Satode (M...
# 306   307     1     1                            Fleming, Miss. Margaret
# 305   306     1     1                     Allison, Master. Hudson Trevor
# 710   711     1     1   Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")
# 711   712     0     1                                 Klaber, Mr. Herman
# 311   312     1     1                         Ryerson, Miss. Emily Borie
# 712   713     1     1                           Taylor, Mr. Elmer Zebley
# 298   299     1     1                              Saalfeld, Mr. Adolphe
# 297   298     0     1                       Allison, Miss. Helen Loraine
# 295   296     0     1                                  Lewy, Mr. Ervin G
# 716   717     1     1                      Endres, Miss. Caroline Louise
# 291   292     1     1            Bishop, Mrs. Dickinson H (Helen Walton)
# 290   291     1     1                       Barber, Miss. Ellen "Nellie"
# 571   572     1     1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 299   300     1     1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 284   285     0     1                         Smith, Mr. Richard William
# 708   709     1     1                               Cleaver, Miss. Alice
#
#          性别     年龄  兄弟姐妹个数  父母子女个数      船票信息        票价               客舱 登船港口
# 445    male   4.00       0       2     33638   81.8583              A34    S
# 310  female  24.00       0       0     11767   83.1583              C54    C
# 309  female  30.00       0       0  PC 17485   56.9292              E36    C
# 307  female  17.00       1       0  PC 17758  108.9000              C65    C
# 306  female    NaN       0       0     17421  110.8833              NaN    C
# 305    male   0.92       1       2    113781  151.5500          C22 C26    S
# 710  female  24.00       0       0  PC 17482   49.5042              C90    C
# 711    male    NaN       0       0    113028   26.5500             C124    S
# 311  female  18.00       2       2  PC 17608  262.3750  B57 B59 B63 B66    C
# 712    male  48.00       1       0     19996   52.0000             C126    S
# 298    male    NaN       0       0     19988   30.5000             C106    S
# 297  female   2.00       1       2    113781  151.5500          C22 C26    S
# 295    male    NaN       0       0  PC 17612   27.7208              NaN    C
# 716  female  38.00       0       0  PC 17757  227.5250              C45    C
# 291  female  19.00       1       0     11967   91.0792              B49    C
# 290  female  26.00       0       0     19877   78.8500              NaN    S
# 571  female  53.00       2       0     11769   51.4792             C101    S
# 299  female  50.00       0       1  PC 17558  247.5208          B58 B60    C
# 284    male    NaN       0       0    113056   26.0000              A19    S
# 708  female  22.00       0       0    113781  151.5500              NaN    S

# %%
#写下你的思考


# 仓位等级为1的存活比例也很高？

# %% [markdown]
# #### 1.6.3 任务三：利用Pandas进行算术计算，计算两个DataFrame数据相加结果

# %%
# 具体请看《利用Python进行数据分析》第五章 算术运算与数据对齐 部分

#自己构建两个都为数字的DataFrame数据

"""
我们举了一个例子：
frame1_a = pd.DataFrame(np.arange(9.).reshape(3, 3),
                     columns=['a', 'b', 'c'],
                     index=['one', 'two', 'three'])
frame1_b = pd.DataFrame(np.arange(12.).reshape(4, 3),
                     columns=['a', 'e', 'c'],
                     index=['first', 'one', 'two', 'second'])
frame1_a
"""

# %%
#代码
frame1_a = pd.DataFrame(np.arange(9.).reshape(3, 3),
                     columns=['a', 'b', 'c'],
                     index=['one', 'two', 'three'])
frame1_b = pd.DataFrame(np.arange(12.).reshape(4, 3),
                     columns=['a', 'e', 'c'],
                     index=['first', 'one', 'two', 'second'])
frame1_a
frame1_b
# Out:
#          a    b    c
# one    0.0  1.0  2.0
# two    3.0  4.0  5.0
# three  6.0  7.0  8.0
#           a     e     c
# first   0.0   1.0   2.0
# one     3.0   4.0   5.0
# two     6.0   7.0   8.0
# second  9.0  10.0  11.0

# %% [markdown]
# 将frame_a和frame_b进行相加

# %%
#代码
df= frame1_a+frame1_b
df
# Out:
#           a   b     c   e
# first   NaN NaN   NaN NaN
# one     3.0 NaN   7.0 NaN
# second  NaN NaN   NaN NaN
# three   NaN NaN   NaN NaN
# two     9.0 NaN  13.0 NaN

# %% [markdown]
# 【提醒】两个DataFrame相加后，会返回一个新的DataFrame，对应的行和列的值会相加，没有对应的会变成空值NaN。<br>
# 当然，DataFrame还有很多算术运算，如减法，除法等，有兴趣的同学可以看《利用Python进行数据分析》第五章 算术运算与数据对齐 部分，多在网络上查找相关学习资料。

# %% [markdown]
# #### 1.6.4 任务四：通过泰坦尼克号数据如何计算出在船上最大的家族有多少人？

# %%
'''
还是用之前导入的chinese_train.csv如果我们想看看在船上，最大的家族有多少人（‘兄弟姐妹个数’+‘父母子女个数’），我们该怎么做呢？
'''
df1
# Out:
# '\n还是用之前导入的chinese_train.csv如果我们想看看在船上，最大的家族有多少人（‘兄弟姐妹个数’+‘父母子女个数’），我们该怎么做呢？\n'
#      乘客ID  是否幸存  仓位等级                                                 姓名  \
# 0       1     0     3                            Braund, Mr. Owen Harris
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     1     3                             Heikkinen, Miss. Laina
# 3       4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5     0     3                           Allen, Mr. William Henry
# ..    ...   ...   ...                                                ...
# 886   887     0     2                              Montvila, Rev. Juozas
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 888   889     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1     1                              Behr, Mr. Karl Howell
# 890   891     0     3                                Dooley, Mr. Patrick
#
#          性别    年龄  兄弟姐妹个数  父母子女个数              船票信息       票价    客舱 登船港口
# 0      male  22.0       1       0         A/5 21171   7.2500   NaN    S
# 1    female  38.0       1       0          PC 17599  71.2833   C85    C
# 2    female  26.0       0       0  STON/O2. 3101282   7.9250   NaN    S
# 3    female  35.0       1       0            113803  53.1000  C123    S
# 4      male  35.0       0       0            373450   8.0500   NaN    S
# ..      ...   ...     ...     ...               ...      ...   ...  ...
# 886    male  27.0       0       0            211536  13.0000   NaN    S
# 887  female  19.0       0       0            112053  30.0000   B42    S
# 888  female   NaN       1       2        W./C. 6607  23.4500   NaN    S
# 889    male  26.0       0       0            111369  30.0000  C148    C
# 890    male  32.0       0       0            370376   7.7500   NaN    Q
#
# [891 rows x 12 columns]

# %%
#代码
df1["家族人数"]= df1['兄弟姐妹个数']+df1['父母子女个数']
df1.sort_values(by="家族人数",ascending=False).head(20)
# Out:
#      乘客ID  是否幸存  仓位等级                                                 姓名  \
# 180   181     0     3                       Sage, Miss. Constance Gladys
# 846   847     0     3                           Sage, Mr. Douglas Bullen
# 792   793     0     3                            Sage, Miss. Stella Anna
# 201   202     0     3                                Sage, Mr. Frederick
# 159   160     0     3                         Sage, Master. Thomas Henry
# 863   864     0     3                  Sage, Miss. Dorothy Edith "Dolly"
# 324   325     0     3                           Sage, Mr. George John Jr
# 386   387     0     3                    Goodwin, Master. Sidney Leonard
# 59     60     0     3                 Goodwin, Master. William Frederick
# 678   679     0     3            Goodwin, Mrs. Frederick (Augusta Tyler)
# 683   684     0     3                        Goodwin, Mr. Charles Edward
# 480   481     0     3                     Goodwin, Master. Harold Victor
# 71     72     0     3                         Goodwin, Miss. Lillian Amy
# 119   120     0     3                  Andersson, Miss. Ellis Anna Maria
# 610   611     0     3  Andersson, Mrs. Anders Johan (Alfrida Konstant...
# 261   262     1     3                  Asplund, Master. Edvin Rojj Felix
# 233   234     1     3                     Asplund, Miss. Lillian Gertrud
# 813   814     0     3                 Andersson, Miss. Ebba Iris Alfrida
# 68     69     1     3                    Andersson, Miss. Erna Alexandra
# 25     26     1     3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
#
#          性别    年龄  兄弟姐妹个数  父母子女个数      船票信息       票价   客舱 登船港口  家族人数
# 180  female   NaN       8       2  CA. 2343  69.5500  NaN    S    10
# 846    male   NaN       8       2  CA. 2343  69.5500  NaN    S    10
# 792  female   NaN       8       2  CA. 2343  69.5500  NaN    S    10
# 201    male   NaN       8       2  CA. 2343  69.5500  NaN    S    10
# 159    male   NaN       8       2  CA. 2343  69.5500  NaN    S    10
# 863  female   NaN       8       2  CA. 2343  69.5500  NaN    S    10
# 324    male   NaN       8       2  CA. 2343  69.5500  NaN    S    10
# 386    male   1.0       5       2   CA 2144  46.9000  NaN    S     7
# 59     male  11.0       5       2   CA 2144  46.9000  NaN    S     7
# 678  female  43.0       1       6   CA 2144  46.9000  NaN    S     7
# 683    male  14.0       5       2   CA 2144  46.9000  NaN    S     7
# 480    male   9.0       5       2   CA 2144  46.9000  NaN    S     7
# 71   female  16.0       5       2   CA 2144  46.9000  NaN    S     7
# 119  female   2.0       4       2    347082  31.2750  NaN    S     6
# 610  female  39.0       1       5    347082  31.2750  NaN    S     6
# 261    male   3.0       4       2    347077  31.3875  NaN    S     6
# 233  female   5.0       4       2    347077  31.3875  NaN    S     6
# 813  female   6.0       4       2    347082  31.2750  NaN    S     6
# 68   female  17.0       4       2   3101281   7.9250  NaN    S     6
# 25   female  38.0       1       5    347077  31.3875  NaN    S     6

# %% [markdown]
# 【提醒】我们只需找出”兄弟姐妹个数“和”父母子女个数“之和最大的数，当然你还可以想出很多方法和思考角度，欢迎你来说出你的看法。

# %% [markdown]
# **多做几个数据的相加，看看你能分析出什么？**

# %%
#代码

# %%
#写下你的其他分析

# %% [markdown]
# #### 1.6.5 任务五：学会使用Pandas describe()函数查看数据基本统计信息

# %%
#(1) 关键知识点示例做一遍（简单数据）
# 具体请看《利用Python进行数据分析》第五章 汇总和计算描述统计 部分

#自己构建一个有数字有空值的DataFrame数据


"""
我们举了一个例子：
frame2 = pd.DataFrame([[1.4, np.nan], 
                       [7.1, -4.5],
                       [np.nan, np.nan], 
                       [0.75, -1.3]
                      ], index=['a', 'b', 'c', 'd'], columns=['one', 'two'])
frame2

"""

# %%
#代码
frame2 = pd.DataFrame([[1.4, np.nan], 
                       [7.1, -4.5],
                       [np.nan, np.nan], 
                       [0.75, -1.3]
                      ], index=['a', 'b', 'c', 'd'], columns=['one', 'two'])

# %% [markdown]
# 调用 describe 函数，观察frame2的数据基本信息

# %%
#代码
frame2.describe()
# Out:
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %% [markdown]
# #### 1.6.6 任务六：分别看看泰坦尼克号数据集中 票价、父母子女 这列数据的基本统计数据，你能发现什么？

# %%
'''
看看泰坦尼克号数据集中 票价 这列数据的基本统计数据
'''

# %%
#代码
df1["票价"].describe
# Out:
# <bound method NDFrame.describe of 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: 票价, Length: 891, dtype: float64>

# %% [markdown]
# 【思考】从上面数据我们可以看出，试试在下面写出你的看法。然后看看我们给出的答案。
#
# 当然，答案只是我的想法，你还可以有更多想法，欢迎写在你的学习笔记中。

# %% [markdown]
# **多做几个组数据的统计，看看你能分析出什么？**

# %%
# 写下你的其他分析

# 就是从不同的维度去看这些数据，背后的drive是看哪些因素正相关的

# %% [markdown]
# 【思考】有更多想法，欢迎写在你的学习笔记中。

# %% [markdown]
# 【总结】本节中我们通过Pandas的一些内置函数对数据进行了初步统计查看，这个过程最重要的不是大家得掌握这些函数，而是看懂从这些函数出来的数据，构建自己的数据分析思维，这也是第一章最重要的点，希望大家学完第一章能对数据有个基本认识，了解自己在做什么，为什么这么做，后面的章节我们将开始对数据进行清洗，进一步分析。
